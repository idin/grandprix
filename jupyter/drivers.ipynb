# %%
from grandprix.ergast import get_drivers

# %%
df = get_drivers(year=2024)

# %%
df
# Out:
#     year        driver_id first_name   last_name         full_name  \
# 0   2024            albon  Alexander       Albon   Alexander Albon
# 1   2024           alonso   Fernando      Alonso   Fernando Alonso
# 2   2024          bearman     Oliver     Bearman    Oliver Bearman
# 3   2024           bottas   Valtteri      Bottas   Valtteri Bottas
# 4   2024        colapinto     Franco   Colapinto  Franco Colapinto
# 5   2024           doohan       Jack      Doohan       Jack Doohan
# 6   2024            gasly     Pierre       Gasly      Pierre Gasly
# 7   2024         hamilton      Lewis    Hamilton    Lewis Hamilton
# 8   2024       hulkenberg       Nico  Hülkenberg   Nico Hülkenberg
# 9   2024           lawson       Liam      Lawson       Liam Lawson
# 10  2024          leclerc    Charles     Leclerc   Charles Leclerc
# 11  2024  kevin_magnussen      Kevin   Magnussen   Kevin Magnussen
# 12  2024           norris      Lando      Norris      Lando Norris
# ...
